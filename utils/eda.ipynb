# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json('../guideline_documents/sa-phc-stg-2024.json')

# %%
df.head(150)
# Out:
#      page_number orientation                     page_header  \
# 0              1    portrait
# 1              2    portrait
# 2              3    portrait                        FOREWORD
# 3              4    portrait
# 4              5    portrait                ACKNOWLEDGEMENTS
# ..           ...         ...                             ...
# 145          146    portrait  CHAPTER 5 \n \nSKIN CONDITIONS
# 146          147    portrait  CHAPTER 5 \n \nSKIN CONDITIONS
# 147          148    portrait  CHAPTER 5 \n \nSKIN CONDITIONS
# 148          149    portrait  CHAPTER 5 \n \nSKIN CONDITIONS
# 149          150    portrait  CHAPTER 5 \n \nSKIN CONDITIONS
#
#                                              page_body        page_footer
# 0    Standard Treatment\nGuidelines and \nEssential...
# 1    Electronic copies are available on National De...
# 2    I proudly present the updated 2024 editions of...                  i
# ...
