# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json('../guideline_documents/sa-phc-stg-2024_pages_with_metadata.json')

# %%
df.iloc[100:200]
# Out:
#      page_number orientation  \
# 100          101    portrait
# 101          102    portrait
# 102          103    portrait
# 103          104    portrait
# 104          105    portrait
# ..           ...         ...
# 195          196    portrait
# 196          197    portrait
# 197          198    portrait
# 198          199    portrait
# 199          200    portrait
#
#                                            page_header  \
# 100               CHAPTER 3 \n \nNUTRITION AND ANAEMIA
# 101           CHAPTER 4 \n \nCARDIOVASCULAR CONDITIONS
# 102           CHAPTER 4 \n \nCARDIOVASCULAR CONDITIONS
# 103           CHAPTER 4 \n \nCARDIOVASCULAR CONDITIONS
# 104           CHAPTER 4 \n \nCARDIOVASCULAR CONDITIONS
# ..                                                 ...
# 195            CHAPTER 6 \n \nOBSTETRICS & GYNAECOLOGY
# 196  CHAPTER 6 \n \nOBSTETRICS & GYNAECOLOGY\n6.4.7...
# 197            CHAPTER 6 \n \nOBSTETRICS & GYNAECOLOGY
# ...
